# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split

# %%
df=pd.read_excel(r"C:\Users\Administrator\Downloads\myntra_dataset_ByScraping.xlsx")

# %%
df.head()
# Out:
#        brand_name           pants_description  price     MRP  \
# 0           WROGN  Men Loose Fit Cotton Jeans   1374  2499.0
# 1  Flying Machine          Men Slim Fit Jeans   1829  2999.0
# 2        Roadster       Men Pure Cotton Jeans    974  2499.0
# 3      Bene Kleed     Relaxed Fit Denim Jeans    873  2299.0
# 4           Levis      Men 511 Slim Fit Jeans   1478  2899.0
#
#    discount_percent  ratings  number_of_ratings
# 0              0.45      4.2                 57
# 1              0.39      4.6                  5
# 2              0.61      3.6               1100
# 3              0.62      4.0               4800
# 4              0.49      4.3                264

# %%
np.random.seed(42)
df['sales']=np.random.randint(10,1000,size=len(df))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52120 entries, 0 to 52119
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand_name         52120 non-null  object
#  1   pants_description  52120 non-null  object
#  2   price              52120 non-null  int64
#  3   MRP                52120 non-null  float64
#  4   discount_percent   52120 non-null  float64
#  5   ratings            52120 non-null  float64
#  6   number_of_ratings  52120 non-null  int64
#  7   sales              52120 non-null  int32
# dtypes: float64(3), int32(1), int64(2), object(2)
# memory usage: 3.0+ MB

# %%
df.describe()
# Out:
#               price           MRP  discount_percent       ratings  \
# count  52120.000000  52120.000000      52120.000000  52120.000000
# mean    1594.515445   3180.398438          1.648256      3.997794
# std     1495.972325   2201.883218          4.687529      0.420404
# min      337.000000    499.000000          0.020000      1.000000
# 25%      989.000000   2499.000000          0.400000      3.800000
# 50%     1439.000000   2999.000000          0.500000      4.000000
# 75%     1829.000000   3499.000000          0.630000      4.200000
# max    54000.000000  72000.000000         64.000000      5.000000
#
#        number_of_ratings         sales
# count       52120.000000  52120.000000
# mean           91.568937    506.735303
# std           433.918513    286.061223
# min             5.000000     10.000000
# 25%            16.000000    259.000000
# 50%            35.000000    510.000000
# 75%            74.000000    754.000000
# max         30700.000000    999.000000

# %%
df.isna().sum()
# Out:
# brand_name           0
# pants_description    0
# price                0
# MRP                  0
# discount_percent     0
# ratings              0
# number_of_ratings    0
# sales                0
# dtype: int64

# %%
df.brand_name.value_counts()
# Out:
# brand_name
# WROGN                        5303
# Flying Machine               5197
# United Colors of Benetton    3985
# Roadster                     3523
# Mufti                        2416
#                              ...
# Happy2r                         1
# INKD                            1
# Bruun & Stengade                1
# Nature Casuals                  1
# Ed Hardy                        1
# Name: count, Length: 417, dtype: int64

# %%
nobrands=df.brand_name.nunique()
print(f'number of brands are {nobrands}')
# Out:
# number of brands are 417

# %%
df.price.max()
# Out:
# 54000

# %%
premium50=df.loc[df.price.nlargest(50).index]
premium50.head(10)
# Out:
#                       brand_name               pants_description  price  \
# 51228                Jacob Cohen     Men Slim Fit Mid-Rise Jeans  54000
# 37202                Jacob Cohen              Men Slim Fit Jeans  53062
# 37203  United Colors of Benetton  Men Relaxed Fit Mid-Rise Jeans  53062
# 18538                Jacob Cohen                       Men Jeans  51750
# 18539              True Religion         Slim Fit Mid-Rise Jeans  51750
# 37312                Jacob Cohen     Mid-Rise Straight Fit Jeans  44625
# 37313  United Colors of Benetton     Men Slim Fit Mid-Rise Jeans  44625
# 18505                 Tramarossa     Men Slim Fit Mid-Rise Jeans  43875
# 25103                 Tramarossa                       Men Jeans  43650
# 25104  United Colors of Benetton  Men Relaxed Fit Mid-Rise Jeans  43650
#
#            MRP  discount_percent  ratings  number_of_ratings  sales
# 51228  72000.0              0.25      4.1                 25    445
# 37202  70750.0              0.25      4.6                  5    924
# 37203  70750.0              0.25      4.6                  5    314
# 18538  57500.0              0.10      3.9                 31    280
# 18539  57500.0              0.10      3.9                 31    123
# 37312  59500.0              0.25      4.2                 42    708
# 37313  59500.0              0.25      4.2                 42    531
# 18505  58500.0              0.25      4.6                  5    955
# 25103  48500.0              0.10      4.6                  5    543
# 25104  48500.0              0.10      4.6                  5    486

# %%
premium50=df.loc[df.price.nlargest(50).index]
premium50.brand_name.value_counts()
# Out:
# brand_name
# True Religion                13
# Tramarossa                   12
# Jacob Cohen                   9
# United Colors of Benetton     7
# Versace Jeans Couture         4
# 7 For All Mankind             2
# MEGHZ                         1
# Karl Lagerfeld                1
# Levis                         1
# Name: count, dtype: int64

# %%
df.price.min()
# Out:
# 337

# %%
df.price.value_counts()
# Out:
# price
# 1829     2481
# 1393     1745
# 2099     1645
# 1399     1508
# 1623     1365
#          ...
# 20625       1
# 1242        1
# 23250       1
# 16350       1
# 1421        1
# Name: count, Length: 1485, dtype: int64

# %%
df['revenue']=df['price']*df['sales']

# %%
df.head()
# Out:
#        brand_name           pants_description  price     MRP  \
# 0           WROGN  Men Loose Fit Cotton Jeans   1374  2499.0
# 1  Flying Machine          Men Slim Fit Jeans   1829  2999.0
# 2        Roadster       Men Pure Cotton Jeans    974  2499.0
# 3      Bene Kleed     Relaxed Fit Denim Jeans    873  2299.0
# 4           Levis      Men 511 Slim Fit Jeans   1478  2899.0
#
#    discount_percent  ratings  number_of_ratings  sales  revenue
# 0              0.45      4.2                 57    112   153888
# 1              0.39      4.6                  5    445   813905
# 2              0.61      3.6               1100    870   847380
# 3              0.62      4.0               4800    280   244440
# 4              0.49      4.3                264    116   171448

# %%
TopRevenue=df.loc[df.revenue.nlargest(20).index]
TopRevenue.brand_name.value_counts()
# Out:
# brand_name
# Tramarossa                   7
# Jacob Cohen                  5
# United Colors of Benetton    4
# True Religion                2
# Versace Jeans Couture        1
# MEGHZ                        1
# Name: count, dtype: int64

# %%
mini=df['price'].min()
maxi=df['price'].max()
print(f'prices range from {mini} to{maxi}')
# Out:
# prices range from 337 to54000

# %%
def pricecategory(df):
    if df['price']<=1000:
        return 'Economical'
    elif df['price']>=1000 and df['price']<=10000:
        return 'Affordable'
    elif df['price']>=10000 and df['price'] <=30000:
        return 'Premium'
    else:
        return 'Luxury'

# %%
df['fashioncategory']=df.apply(lambda x:pricecategory(x),axis=1)
df.head()
# Out:
#        brand_name           pants_description  price     MRP  \
# 0           WROGN  Men Loose Fit Cotton Jeans   1374  2499.0
# 1  Flying Machine          Men Slim Fit Jeans   1829  2999.0
# 2        Roadster       Men Pure Cotton Jeans    974  2499.0
# 3      Bene Kleed     Relaxed Fit Denim Jeans    873  2299.0
# 4           Levis      Men 511 Slim Fit Jeans   1478  2899.0
#
#    discount_percent  ratings  number_of_ratings  sales  revenue  \
# 0              0.45      4.2                 57    112   153888
# 1              0.39      4.6                  5    445   813905
# 2              0.61      3.6               1100    870   847380
# 3              0.62      4.0               4800    280   244440
# 4              0.49      4.3                264    116   171448
#
#   fashioncategory
# 0      Affordable
# 1      Affordable
# 2      Economical
# 3      Economical
# 4      Affordable

# %%
##price distribution

sns.histplot(TopRevenue,x=TopRevenue['price'],hue=TopRevenue['brand_name'],palette='winter')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.countplot(Toprated['fashioncategory'])
# Out:
# <Axes: xlabel='count', ylabel='fashioncategory'>

# %%
luxbrands=df.loc[df['fashioncategory']=='Luxury']
luxbrands.brand_name.value_counts()
# Out:
# brand_name
# Tramarossa                   10
# Jacob Cohen                   9
# United Colors of Benetton     6
# True Religion                 4
# Versace Jeans Couture         2
# MEGHZ                         1
# Name: count, dtype: int64

# %%
ecobrands=df.loc[df['fashioncategory']=='Economical']
ecobrands.brand_name.value_counts()
# Out:
# brand_name
# Roadster                     3278
# United Colors of Benetton     861
# LINARIA                       811
# glitchez                      795
# COMFITS                       489
#                              ...
# INKD                            1
# boohooMAN                       1
# Chapter 2                       1
# Off Duty India                  1
# Iconic                          1
# Name: count, Length: 240, dtype: int64

# %%
Nlux=luxbrands.brand_name.nunique()
Neco=ecobrands.brand_name.nunique()
Npre=premiumbrands.brand_name.nunique()
Naff=affbrands.brand_name.nunique()
print(f'no. luxury brands {Nlux} ,economical brands are {Neco},premium are {Npre},afforable are {Naff}')
# Out:
# no. luxury brands 6 ,economical brands are 240,premium are 16,afforable are 344

# %%
premiumbrands=df.loc[df['fashioncategory']=='Premium']
premiumbrands.brand_name.value_counts()
# Out:
# brand_name
# True Religion                66
# United Colors of Benetton    14
# 7 For All Mankind            12
# Calvin Klein Jeans            9
# Polo Ralph Lauren             7
# HACKETT LONDON                5
# Versace Jeans Couture         3
# Tramarossa                    2
# Karl Lagerfeld                2
# ADIDAS Originals              1
# Levis                         1
# Andamen                       1
# Just Cavalli                  1
# Snitch                        1
# V-Mart                        1
# JIMMY & JORDAN                1
# Name: count, dtype: int64

# %%
affbrands=df.loc[df['fashioncategory']=='Affordable']
affbrands.brand_name.value_counts()
# Out:
# brand_name
# Flying Machine               5167
# WROGN                        5131
# United Colors of Benetton    3104
# Mufti                        2411
# Levis                        2139
#                              ...
# LEG UP                          1
# Breakbounce                     1
# ADIDAS Originals                1
# Pupil London                    1
# Ed Hardy                        1
# Name: count, Length: 344, dtype: int64

# %%
Toprated=df[df['ratings']==5]
Toprated=Toprated.sort_values(by='ratings',ascending=False).head(10)
Toprated
# Out:
#                       brand_name               pants_description  price  \
# 1597                    Roadster             Washed Effect Jeans    890
# 38536             Flying Machine              Men Slim Fit Jeans   1549
# 38103  United Colors of Benetton  Men Relaxed Fit Mid-Rise Jeans   1299
# 38102                 Pepe Jeans  Men Slim Fit Stretchable Jeans   1299
# 37893                     Octave   Men Mid-Rise Clean Look Jeans   1689
# 35648  United Colors of Benetton     Men Anti Fit Mid-Rise Jeans   1749
# 35647                     SPYKAR           Men Relaxed Fit Jeans   1749
# 35646                     WAIMEA               Men Bootcut Jeans   3849
# 35394                 John Pride      Men Plus Size Jogger Jeans   3374
# 35164              True Religion            Men Skinny Fit Jeans  13199
#
#            MRP  discount_percent  ratings  number_of_ratings  sales  revenue  \
# 1597    2699.0              0.67      5.0                  9    484   430760
# 38536   2499.0              0.38      5.0                  5    527   816323
# 38103   3599.0             23.00      5.0                  6    450   584550
# 38102   3599.0             23.00      5.0                  6    667   866433
# 37893   2599.0              0.35      5.0                  5    203   342867
# 35648   3499.0              0.50      5.0                  6    294   514206
# 35647   3499.0              0.50      5.0                  6    578  1010922
# 35646   6999.0              0.45      5.0                  6    840  3233160
# 35394   4499.0              0.25      5.0                  5    979  3303146
# 35164  21999.0              0.40      5.0                  7    473  6243127
#
#       fashioncategory
# 1597       Economical
# 38536      Affordable
# 38103      Affordable
# 38102      Affordable
# 37893      Affordable
# 35648      Affordable
# 35647      Affordable
# 35646      Affordable
# 35394      Affordable
# 35164         Premium

# %%
plt.figure(figsize=(10,5))
plt.bar(Toprated['brand_name'],Toprated['number_of_ratings'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.barplot(x=Toprated['brand_name'],y=Toprated['number_of_ratings'],hue=Toprated['fashioncategory'],palette='winter')
plt.show()

# %%
df['high_rating']=(df['ratings']>=4).astype(int)
df.high_rating.value_counts(normalize=True)
# Out:
# high_rating
# 1    0.610975
# 0    0.389025
# Name: proportion, dtype: float64

# %%
import plotly.express as px
fig=px.pie(df,names='high_rating',color='high_rating',
           color_discrete_map={1:'Green',
                              0:'Red'})
fig.show()

# %%
Highend=df.loc[df['high_rating']==1]
Highend=Highend.head(100)

# %%
fig=px.sunburst(Highend,path=['brand_name','price','MRP','discount_percent','ratings','number_of_ratings','sales'])
fig.show()

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
for i in df:
    if df[i].dtypes in ['int64','float64']:
        q1=df[i].quantile(0.75)
        q3=df[i].quantile(0.25)
        iqr=q3-q1
        ul=q1+1.5*iqr
        ll=q3-1.5*iqr
        df[i].clip(upper=ul,lower=ll,inplace=True)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8052\2913403554.py:8: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8052\2913403554.py:8: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8052\2913403554.py:8: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8052\2913403554.py:8: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8052\2913403554.py:8: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8052\2913403554.py:8: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8052\2913403554.py:8: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1512370.125' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8052\2913403554.py:8: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %% [markdown]
# ## Breaking into two parts

# %%
df.head()
# Out:
#        brand_name           pants_description  price     MRP  \
# 0           WROGN  Men Loose Fit Cotton Jeans   1374  2499.0
# 1  Flying Machine          Men Slim Fit Jeans   1829  2999.0
# 2        Roadster       Men Pure Cotton Jeans    974  2499.0
# 3      Bene Kleed     Relaxed Fit Denim Jeans    873  2299.0
# 4           Levis      Men 511 Slim Fit Jeans   1478  2899.0
#
#    discount_percent  ratings  number_of_ratings  sales   revenue  \
# 0              0.45      4.2                 57    112  153888.0
# 1              0.39      4.4                  5    445  813905.0
# 2              0.61      3.6                103    870  847380.0
# 3              0.62      4.0                103    280  244440.0
# 4              0.49      4.3                103    116  171448.0
#
#   fashioncategory  high_rating
# 0      Affordable            1
# 1      Affordable            1
# 2      Economical            0
# 3      Economical            1
# 4      Affordable            1

# %%
quantitative=df.select_dtypes(include=[np.number])
quantitative.head()
# Out:
#    price     MRP  discount_percent  ratings  number_of_ratings  sales  \
# 0   1374  2499.0              0.45      4.2                 57    112
# 1   1829  2999.0              0.39      4.4                  5    445
# 2    974  2499.0              0.61      3.6                103    870
# 3    873  2299.0              0.62      4.0                103    280
# 4   1478  2899.0              0.49      4.3                103    116
#
#     revenue  high_rating
# 0  153888.0            1
# 1  813905.0            1
# 2  847380.0            0
# 3  244440.0            1
# 4  171448.0            1

# %%
correlation=quantitative.corr()
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
qualitative=df.select_dtypes(include=['object'])
qualitative.head()
# Out:
#        brand_name           pants_description fashioncategory
# 0           WROGN  Men Loose Fit Cotton Jeans      Affordable
# 1  Flying Machine          Men Slim Fit Jeans      Affordable
# 2        Roadster       Men Pure Cotton Jeans      Economical
# 3      Bene Kleed     Relaxed Fit Denim Jeans      Economical
# 4           Levis      Men 511 Slim Fit Jeans      Affordable

# %% [markdown]
# #### Converting qualitative into number

# %%
from sklearn.preprocessing import LabelEncoder
qualitative=qualitative.apply(LabelEncoder().fit_transform)
qualitative.head()
# Out:
#    brand_name  pants_description  fashioncategory
# 0         391               1168                0
# 1         130               1802                0
# 2         300               1520                1
# 3          49               2426                1
# 4         210                392                0

# %%
Finaldf=pd.concat([qualitative,quantitative],axis=1)
Finaldf.head()
# Out:
#    brand_name  pants_description  fashioncategory  price     MRP  \
# 0         391               1168                0   1374  2499.0
# 1         130               1802                0   1829  2999.0
# 2         300               1520                1    974  2499.0
# 3          49               2426                1    873  2299.0
# 4         210                392                0   1478  2899.0
#
#    discount_percent  ratings  number_of_ratings  sales   revenue  high_rating
# 0              0.45      4.2                 57    112  153888.0            1
# 1              0.39      4.4                  5    445  813905.0            1
# 2              0.61      3.6                103    870  847380.0            0
# 3              0.62      4.0                103    280  244440.0            1
# 4              0.49      4.3                103    116  171448.0            1

# %%
Finaldf.columns.to_list()
# Out:
# ['brand_name',
#  'pants_description',
#  'fashioncategory',
#  'price',
#  'MRP',
#  'discount_percent',
#  'ratings',
#  'number_of_ratings',
#  'sales',
#  'revenue',
#  'high_rating']

# %% [markdown]
# ## Data Partition

# %%
from sklearn.model_selection import train_test_split
x=Finaldf.drop(['ratings','high_rating','sales','revenue'],axis=1)
y=Finaldf['high_rating']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %% [markdown]
# ## StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
new_xtrain=sc.fit_transform(x_train)
new_xtest=sc.transform(x_test)

# %%
new_xtrain
# Out:
# array([[ 1.39932457,  0.18330949,  1.58386269, ..., -1.42266461,
#          0.65103107, -0.12150264],
#        [-1.50332148, -0.81058944, -0.58559392, ..., -0.26681385,
#          0.87040347, -0.51258602],
#        [-1.04731666,  0.5072876 , -0.58559392, ...,  0.02214884,
#         -0.95769987, -1.15508016],
#        ...,
#        [ 0.97839705, -0.30174247, -0.58559392, ...,  1.03351826,
#          0.066038  , -1.07127657],
#        [-1.04731666,  1.80869117, -0.58559392, ...,  0.02214884,
#         -0.95769987, -1.0992111 ],
#        [ 0.03131012,  0.08263833, -0.58559392, ...,  1.4669623 ,
#         -0.1533344 ,  0.15784264]], shape=(36484, 7))

# %%
new_xtest
# Out:
# array([[ 1.24147675, -1.99850915, -0.58559392, ..., -0.26681385,
#         -0.1533344 , -0.59638961],
#        [ 0.57500817,  0.52559144, -0.58559392, ...,  0.88903692,
#         -0.1533344 ,  1.58250354],
#        [ 1.24147675, -0.65317635, -0.58559392, ..., -0.70025789,
#         -0.51895506,  0.29751528],
#        ...,
#        [ 1.03978231,  0.53474337, -0.58559392, ...,  1.4669623 ,
#          1.52852067, -0.12150264],
#        [ 0.86439584,  0.76903262,  1.58386269, ..., -0.62801721,
#          1.45539654,  1.58250354],
#        [ 1.24147675, -0.65317635, -0.58559392, ..., -0.70025789,
#         -0.51895506,  0.29751528]], shape=(15636, 7))

# %% [markdown]
# ## Model Building

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()
classifier.fit(new_xtrain,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn .metrics import confusion_matrix
y_trainpred=classifier.predict(new_xtrain)
confusion_matrix(y_train,y_trainpred)
# Out:
# array([[ 3231, 10919],
#        [ 2866, 19468]])

# %%
from sklearn.metrics import accuracy_score
print('Accuracy =' ,accuracy_score(y_train,y_trainpred))
# Out:
# Accuracy = 0.6221631400065782

# %%
y_testpred=classifier.predict(new_xtest)

# %%
from sklearn.metrics import confusion_matrix
confusionmatrix=confusion_matrix(y_test,y_testpred)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_testpred))
print(confusionmatrix)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.23      0.32      6126
#            1       0.64      0.87      0.74      9510
#
#     accuracy                           0.62     15636
#    macro avg       0.59      0.55      0.53     15636
# weighted avg       0.60      0.62      0.57     15636
#
# [[1384 4742]
#  [1208 8302]]

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
high_rating=['0','1']

# %%
from sklearn import tree

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

independentvariables=list(x.columns)
high_rating=['1','0']

fig,axes=plt.subplots(nrows=1,ncols=1,dpi=300,figsize=(4,5))
plot_tree(dt,
         feature_names=list(x.columns),
         class_names=high_rating,
         filled=True,
         fontsize=2)

# %%
DTtrain=pd.concat([x_train,y_train],axis=1)
DTtrain.head()
# Out:
#        brand_name  pants_description  fashioncategory  price     MRP  \
# 21812         409               1625                1    623  1999.0
# 4514           78               1082                0   1007  2799.0
# 36151         130               1802                0   1829  2999.0
# 31096         126               1620                0   2099  3499.0
# 47199         269               1056                0   2249  3999.0
#
#        discount_percent  number_of_ratings  high_rating
# 21812              0.61                 42            1
# 4514               0.64                 28            0
# 36151              0.39                  5            1
# 31096              0.40                103            0
# 47199              0.40                 22            0

# %%
DTtrain['preds']=dt.predict(x_train)
DTtrain.head()
# Out:
#        brand_name  pants_description  fashioncategory  price     MRP  \
# 21812         409               1625                1    623  1999.0
# 4514           78               1082                0   1007  2799.0
# 36151         130               1802                0   1829  2999.0
# 31096         126               1620                0   2099  3499.0
# 47199         269               1056                0   2249  3999.0
#
#        discount_percent  number_of_ratings  high_rating  preds
# 21812              0.61                 42            1      1
# 4514               0.64                 28            0      0
# 36151              0.39                  5            1      1
# 31096              0.40                103            0      0
# 47199              0.40                 22            0      0

# %%
from sklearn.metrics import classification_report
report=classification_report(DTtrain['high_rating'],DTtrain['preds'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     14150
#            1       0.99      0.98      0.98     22334
#
#     accuracy                           0.98     36484
#    macro avg       0.98      0.98      0.98     36484
# weighted avg       0.98      0.98      0.98     36484

# %%
params={'min_samples_split':[250,200,150],
       'min_samples_leaf':[100,50,40],
       'max_depth':[3,4,5]}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

grid=GridSearchCV(DecisionTreeClassifier(random_state=99),
                params,
                verbose=1,
                cv=3)
grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(random_state=99),
#              param_grid={'max_depth': [3, 4, 5],
#                          'min_samples_leaf': [100, 50, 40],
#                          'min_samples_split': [250, 200, 150]},
#              verbose=1)

# %%
DT=DecisionTreeClassifier(max_depth=5, min_samples_leaf=100, min_samples_split=250,
                       random_state=99)
DT.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=100, min_samples_split=250,
#                        random_state=99)

# %%
high_rating=['0','1']

# %%
from sklearn import tree
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

fig,axes=plt.subplots(nrows=1,ncols=1,dpi=300,figsize=(4,5))

plot_tree(DT,
         feature_names=list(x.columns),
         class_names=high_rating,
         filled=True,
         node_ids=True,
         fontsize=2)
# Out:
# [Text(0.5229166666666667, 0.9166666666666666, 'node #0\nnumber_of_ratings <= 35.5\ngini = 0.475\nsamples = 36484\nvalue = [14150, 22334]\nclass = 1'),
#  Text(0.26666666666666666, 0.75, 'node #1\nnumber_of_ratings <= 30.5\ngini = 0.499\nsamples = 19091\nvalue = [9889, 9202]\nclass = 0'),
#  Text(0.39479166666666665, 0.8333333333333333, 'True  '),
#  Text(0.13333333333333333, 0.5833333333333334, 'node #2\nnumber_of_ratings <= 5.5\ngini = 0.491\nsamples = 15511\nvalue = [6711, 8800]\nclass = 1'),
#  Text(0.06666666666666667, 0.4166666666666667, 'node #3\nprice <= 1598.0\ngini = 0.266\nsamples = 3229\nvalue = [509, 2720]\nclass = 1'),
#  Text(0.03333333333333333, 0.25, 'node #4\nprice <= 598.5\ngini = 0.385\nsamples = 1106\nvalue = [288, 818]\nclass = 1'),
#  Text(0.016666666666666666, 0.08333333333333333, 'node #5\ngini = 0.321\nsamples = 269\nvalue = [54, 215]\nclass = 1'),
#  Text(0.05, 0.08333333333333333, 'node #6\ngini = 0.403\nsamples = 837\nvalue = [234.0, 603.0]\nclass = 1'),
#  Text(0.1, 0.25, 'node #7\nprice <= 1921.0\ngini = 0.187\nsamples = 2123\nvalue = [221, 1902]\nclass = 1'),
#  Text(0.08333333333333333, 0.08333333333333333, 'node #8\ngini = 0.093\nsamples = 1532\nvalue = [75, 1457]\nclass = 1'),
#  Text(0.11666666666666667, 0.08333333333333333, 'node #9\ngini = 0.372\nsamples = 591\nvalue = [146, 445]\nclass = 1'),
#  Text(0.2, 0.4166666666666667, 'node #10\nnumber_of_ratings <= 24.5\ngini = 0.5\nsamples = 12282\nvalue = [6202.0, 6080.0]\nclass = 0'),
#  Text(0.16666666666666666, 0.25, 'node #11\nMRP <= 3457.0\ngini = 0.484\nsamples = 9814\nvalue = [5779.0, 4035.0]\nclass = 0'),
#  Text(0.15, 0.08333333333333333, 'node #12\ngini = 0.455\nsamples = 6056\nvalue = [3939, 2117]\nclass = 0'),
#  Text(0.18333333333333332, 0.08333333333333333, 'node #13\ngini = 0.5\nsamples = 3758\nvalue = [1840.0, 1918.0]\nclass = 1'),
#  Text(0.23333333333333334, 0.25, 'node #14\nnumber_of_ratings <= 25.5\ngini = 0.284\nsamples = 2468\nvalue = [423, 2045]\nclass = 1'),
#  Text(0.21666666666666667, 0.08333333333333333, 'node #15\ngini = 0.109\nsamples = 1613\nvalue = [93, 1520]\nclass = 1'),
#  Text(0.25, 0.08333333333333333, 'node #16\ngini = 0.474\nsamples = 855\nvalue = [330, 525]\nclass = 1'),
#  Text(0.4, 0.5833333333333334, 'node #17\nnumber_of_ratings <= 31.5\ngini = 0.199\nsamples = 3580\nvalue = [3178, 402]\nclass = 0'),
#  Text(0.3333333333333333, 0.4166666666666667, 'node #18\nprice <= 1542.0\ngini = 0.065\nsamples = 2228\nvalue = [2153, 75]\nclass = 0'),
#  Text(0.3, 0.25, 'node #19\nprice <= 1238.0\ngini = 0.147\nsamples = 587\nvalue = [540.0, 47.0]\nclass = 0'),
#  Text(0.2833333333333333, 0.08333333333333333, 'node #20\ngini = 0.092\nsamples = 433\nvalue = [412, 21]\nclass = 0'),
#  Text(0.31666666666666665, 0.08333333333333333, 'node #21\ngini = 0.281\nsamples = 154\nvalue = [128, 26]\nclass = 0'),
#  Text(0.36666666666666664, 0.25, 'node #22\npants_description <= 589.0\ngini = 0.034\nsamples = 1641\nvalue = [1613, 28]\nclass = 0'),
#  Text(0.35, 0.08333333333333333, 'node #23\ngini = 0.0\nsamples = 777\nvalue = [777, 0]\nclass = 0'),
#  Text(0.38333333333333336, 0.08333333333333333, 'node #24\ngini = 0.063\nsamples = 864\nvalue = [836, 28]\nclass = 0'),
#  Text(0.4666666666666667, 0.4166666666666667, 'node #25\nnumber_of_ratings <= 34.5\ngini = 0.367\nsamples = 1352\nvalue = [1025, 327]\nclass = 0'),
#  Text(0.43333333333333335, 0.25, 'node #26\nprice <= 1061.5\ngini = 0.489\nsamples = 433\nvalue = [184, 249]\nclass = 1'),
#  Text(0.4166666666666667, 0.08333333333333333, 'node #27\ngini = 0.474\nsamples = 119\nvalue = [73, 46]\nclass = 0'),
#  Text(0.45, 0.08333333333333333, 'node #28\ngini = 0.457\nsamples = 314\nvalue = [111.0, 203.0]\nclass = 1'),
#  Text(0.5, 0.25, 'node #29\nprice <= 820.5\ngini = 0.155\nsamples = 919\nvalue = [841, 78]\nclass = 0'),
#  Text(0.48333333333333334, 0.08333333333333333, 'node #30\ngini = 0.031\nsamples = 581\nvalue = [572, 9]\nclass = 0'),
#  Text(0.5166666666666667, 0.08333333333333333, 'node #31\ngini = 0.325\nsamples = 338\nvalue = [269, 69]\nclass = 0'),
#  Text(0.7791666666666667, 0.75, 'node #32\nnumber_of_ratings <= 63.5\ngini = 0.37\nsamples = 17393\nvalue = [4261, 13132]\nclass = 1'),
#  Text(0.6510416666666667, 0.8333333333333333, '  False'),
#  Text(0.6666666666666666, 0.5833333333333334, 'node #33\ndiscount_percent <= 0.605\ngini = 0.233\nsamples = 7611\nvalue = [1026, 6585]\nclass = 1'),
#  Text(0.6, 0.4166666666666667, 'node #34\nnumber_of_ratings <= 62.5\ngini = 0.159\nsamples = 5975\nvalue = [519, 5456]\nclass = 1'),
#  Text(0.5666666666666667, 0.25, 'node #35\nbrand_name <= 370.5\ngini = 0.222\nsamples = 3979\nvalue = [507, 3472]\nclass = 1'),
#  Text(0.55, 0.08333333333333333, 'node #36\ngini = 0.315\nsamples = 2214\nvalue = [434, 1780]\nclass = 1'),
#  Text(0.5833333333333334, 0.08333333333333333, 'node #37\ngini = 0.079\nsamples = 1765\nvalue = [73, 1692]\nclass = 1'),
#  Text(0.6333333333333333, 0.25, 'node #38\nMRP <= 2487.0\ngini = 0.012\nsamples = 1996\nvalue = [12, 1984]\nclass = 1'),
#  Text(0.6166666666666667, 0.08333333333333333, 'node #39\ngini = 0.0\nsamples = 1073\nvalue = [0, 1073]\nclass = 1'),
#  Text(0.65, 0.08333333333333333, 'node #40\ngini = 0.026\nsamples = 923\nvalue = [12, 911]\nclass = 1'),
#  Text(0.7333333333333333, 0.4166666666666667, 'node #41\nnumber_of_ratings <= 62.5\ngini = 0.428\nsamples = 1636\nvalue = [507.0, 1129.0]\nclass = 1'),
#  Text(0.7, 0.25, 'node #42\nnumber_of_ratings <= 42.5\ngini = 0.471\nsamples = 1298\nvalue = [494, 804]\nclass = 1'),
#  Text(0.6833333333333333, 0.08333333333333333, 'node #43\ngini = 0.367\nsamples = 640\nvalue = [155, 485]\nclass = 1'),
#  Text(0.7166666666666667, 0.08333333333333333, 'node #44\ngini = 0.5\nsamples = 658\nvalue = [339, 319]\nclass = 0'),
#  Text(0.7666666666666667, 0.25, 'node #45\ndiscount_percent <= 0.725\ngini = 0.074\nsamples = 338\nvalue = [13, 325]\nclass = 1'),
#  Text(0.75, 0.08333333333333333, 'node #46\ngini = 0.142\nsamples = 130\nvalue = [10, 120]\nclass = 1'),
#  Text(0.7833333333333333, 0.08333333333333333, 'node #47\ngini = 0.028\nsamples = 208\nvalue = [3, 205]\nclass = 1'),
#  Text(0.8916666666666667, 0.5833333333333334, 'node #48\nbrand_name <= 129.0\ngini = 0.443\nsamples = 9782\nvalue = [3235.0, 6547.0]\nclass = 1'),
#  Text(0.85, 0.4166666666666667, 'node #49\nbrand_name <= 125.5\ngini = 0.493\nsamples = 1902\nvalue = [1061, 841]\nclass = 0'),
#  Text(0.8333333333333334, 0.25, 'node #50\nbrand_name <= 77.5\ngini = 0.422\nsamples = 1202\nvalue = [364, 838]\nclass = 1'),
#  Text(0.8166666666666667, 0.08333333333333333, 'node #51\ngini = 0.345\nsamples = 794\nvalue = [176, 618]\nclass = 1'),
#  Text(0.85, 0.08333333333333333, 'node #52\ngini = 0.497\nsamples = 408\nvalue = [188, 220]\nclass = 1'),
#  Text(0.8666666666666667, 0.25, 'node #53\ngini = 0.009\nsamples = 700\nvalue = [697, 3]\nclass = 0'),
#  Text(0.9333333333333333, 0.4166666666666667, 'node #54\nprice <= 1227.0\ngini = 0.4\nsamples = 7880\nvalue = [2174, 5706]\nclass = 1'),
#  Text(0.9, 0.25, 'node #55\nbrand_name <= 200.0\ngini = 0.497\nsamples = 2780\nvalue = [1282, 1498]\nclass = 1'),
#  Text(0.8833333333333333, 0.08333333333333333, 'node #56\ngini = 0.458\nsamples = 519\nvalue = [335, 184]\nclass = 0'),
#  Text(0.9166666666666666, 0.08333333333333333, 'node #57\ngini = 0.487\nsamples = 2261\nvalue = [947, 1314]\nclass = 1'),
#  Text(0.9666666666666667, 0.25, 'node #58\nprice <= 1278.0\ngini = 0.289\nsamples = 5100\nvalue = [892, 4208]\nclass = 1'),
#  Text(0.95, 0.08333333333333333, 'node #59\ngini = 0.059\nsamples = 981\nvalue = [30, 951]\nclass = 1'),
#  Text(0.9833333333333333, 0.08333333333333333, 'node #60\ngini = 0.331\nsamples = 4119\nvalue = [862, 3257]\nclass = 1')]

# %%
DTtrain['predicted']=DT.predict(x_train)
DTtrain.head()
# Out:
#        brand_name  pants_description  fashioncategory  price     MRP  \
# 21812         409               1625                1    623  1999.0
# 4514           78               1082                0   1007  2799.0
# 36151         130               1802                0   1829  2999.0
# 31096         126               1620                0   2099  3499.0
# 47199         269               1056                0   2249  3999.0
#
#        discount_percent  number_of_ratings  high_rating  preds  predicted
# 21812              0.61                 42            1      1          1
# 4514               0.64                 28            0      0          1
# 36151              0.39                  5            1      1          1
# 31096              0.40                103            0      0          0
# 47199              0.40                 22            0      0          1

# %%
report=classification_report(DTtrain['high_rating'],DTtrain['predicted'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.59      0.66     14150
#            1       0.77      0.87      0.82     22334
#
#     accuracy                           0.76     36484
#    macro avg       0.76      0.73      0.74     36484
# weighted avg       0.76      0.76      0.76     36484

# %%
matrix=confusion_matrix(DTtrain['high_rating'],DTtrain['predicted'])
print(matrix)
# Out:
# [[ 8377  5773]
#  [ 2822 19512]]

# %%
DTtest=pd.concat([x_test,y_test],axis=1)
DTtest.head()
# Out:
#        brand_name  pants_description  fashioncategory  price     MRP  \
# 8481          391                433                0   1399  2799.0
# 26182         315               1812                0   1799  3599.0
# 27700         391               1168                0   1374  2499.0
# 8952          372               1082                0   1829  2999.0
# 23094         315               1570                0   1899  3799.0
#
#        discount_percent  number_of_ratings  high_rating
# 8481               0.50                 25            1
# 26182              0.50                103            1
# 27700              0.45                 57            1
# 8952               0.39                  5            1
# 23094              0.50                 31            0

# %%
DTtest['predicted']=DT.predict(x_test)
DTtest.head()
# Out:
#        brand_name  pants_description  fashioncategory  price     MRP  \
# 8481          391                433                0   1399  2799.0
# 26182         315               1812                0   1799  3599.0
# 27700         391               1168                0   1374  2499.0
# 8952          372               1082                0   1829  2999.0
# 23094         315               1570                0   1899  3799.0
#
#        discount_percent  number_of_ratings  high_rating  predicted
# 8481               0.50                 25            1          1
# 26182              0.50                103            1          1
# 27700              0.45                 57            1          1
# 8952               0.39                  5            1          1
# 23094              0.50                 31            0          0

# %%
report=classification_report(DTtest['high_rating'],DTtest['predicted'])
print(report)

matrix=confusion_matrix(DTtest['high_rating'],DTtest['predicted'])
print(matrix)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.59      0.66      6126
#            1       0.77      0.87      0.81      9510
#
#     accuracy                           0.76     15636
#    macro avg       0.76      0.73      0.74     15636
# weighted avg       0.76      0.76      0.75     15636
#
# [[3591 2535]
#  [1228 8282]]

# %%
matrix=confusion_matrix(DTtest['high_rating'],DTtest['predicted'])
print(matrix)
# Out:
# [[3591 2535]
#  [1228 8282]]
